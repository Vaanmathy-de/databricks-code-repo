# %% [markdown]
# #Notebook Learning

# %% [markdown]
# ##1.Added image using url
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTuE6tRqzZlFtQoMmVonZEYu5-1O36Ms8jPjA&s)

# %% [markdown]
# ##2.Bold , Italics ,Colors in Bullets
# - **This text is in BOLD**
# - _My favourite font is Italics_
# - $$\textcolor{Red}{\text {Red suits me well}}$$
# - $$\textcolor{Blue}{\text {Sky looks beautiful}}$$
# - $$\textcolor{Green}{\text {The Grass is greener on other side}}$$
# - $$\textcolor{Cyan}{\text {Maldives water cyan color}}$$

# %% [markdown]
# ####How to call a notebook from the current notebook using %run magic command

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.volumenew_datalake;

# %%
# %fs ls "dbfs:///Volumes/workspace/default/volumenew_datalake"

# %%
# %fs cp "dbfs:/Volumes/workspace/default/volumenew_datalake/patients.csv" "dbfs:/Volumes/workspace/default/volumenew_datalake/patients_copy.csv"

# %%
# %python
dbutils.fs.cp("dbfs:/Volumes/workspace/default/volumenew_datalake/patients.csv","dbfs:/Volumes/workspace/default/volumenew_datalake/patients_copy2.csv")
dbutils.fs.rm("dbfs:/Volumes/workspace/default/volumenew_datalake/patients_copy.csv")

# %%
# %sql
create table if not exists default.cities2(id int,city string);
insert into default.cities2 values(3,'Mumbai'),(4,'Lucknow');
select * from cities2;

# %%
# %python
spark.sql("select * from cities2").explain(True)

# %%
# %sql
UPDATE workspace.default.cities2
SET city = 'Kolkata'
WHERE id = 4;

# %%
# %sql
SHOW CREATE TABLE workspace.default.cities2;

# %%
def sqrt(a):
    return a*a

# %%
print("square root function call ",sqrt(10))

# %%
# %python
from pyspark.sql.session import SparkSession
print(spark)
spark1 = SparkSession.builder.appName("Spark DataFrames").getOrCreate()
print(spark1)
df1 = spark1.read.csv("/Volumes/workspace/default/volumewe47_datalake/patients.csv",header=True)
display(df1)

# %%
# %pip install pypi
